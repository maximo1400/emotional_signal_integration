# %%
import pandas as pd
import numpy as np
import pyarrow.feather as feather

# %%
df = feather.read_feather('dreamer_bandpower_frames.feather')
print(df.head())
# Out:
#    subject_id  trial_id clip_id  valence  arousal  dominance baseline_id  \
# 0           0         0     0_1        4        3          2         0_0
# 1           0         0     0_1        4        3          2         0_0
# 2           0         0     0_1        4        3          2         0_0
# 3           0         0     0_1        4        3          2         0_0
# 4           0         0     0_1        4        3          2         0_0
#
#    frame_time  AF3/theta  AF3/alpha  ...   F8/theta   F8/alpha   F8/betaL  \
# 0       1.000   9.491933  -6.370030  ...  20.545517  11.109631  11.429152
# 1       1.125   9.779720  -6.608766  ...  20.348896   9.883400  10.840242
# 2       1.250   9.693452  -6.831704  ...  20.567553   8.494941  10.226957
# 3       1.375   9.245693  -6.969596  ...  20.980589   7.570346   9.995745
# 4       1.500   8.501300  -6.906187  ...  21.392881   7.890661  10.310887
#
#     F8/betaH   F8/gamma  AF4/theta  AF4/alpha  AF4/betaL  AF4/betaH  AF4/gamma
# ...

# %%
df.shape
# Out:
# (679742, 78)

# %%
df.groupby('subject_id').size()
# Out:
# subject_id
# 0     29554
# 1     29554
# 2     29554
# 3     29554
# 4     29554
# 5     29554
# 6     29554
# 7     29554
# 8     29554
# 9     29554
# 10    29554
# 11    29554
# 12    29554
# 13    29554
# 14    29554
# 15    29554
# 16    29554
# 17    29554
# 18    29554
# 19    29554
# 20    29554
# 21    29554
# 22    29554
# dtype: int64

# %%
df['valence'].describe()
# Out:
# count    679742.000000
# mean          2.984200
# std           1.377954
# min           1.000000
# 25%           2.000000
# 50%           3.000000
# 75%           4.000000
# max           5.000000
# Name: valence, dtype: float64
